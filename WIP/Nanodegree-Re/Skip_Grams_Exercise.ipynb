# %% [markdown]
# # Skip-gram Word2Vec
#
# In this notebook, I'll lead you through using PyTorch to implement the [Word2Vec algorithm](https://en.wikipedia.org/wiki/Word2vec) using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of Word2Vec from Chris McCormick
# * [First Word2Vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [Neural Information Processing Systems, paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for Word2Vec also from Mikolov et al.
#
# ---
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of word classes to analyze; one for each word in a vocabulary. Trying to one-hot encode these words is massively inefficient because most values in a one-hot vector will be set to zero. So, the matrix multiplication that happens in between a one-hot input vector and a first, hidden layer will result in mostly zero-valued hidden outputs.
#
# <img src='assets/one_hot_encoding.png' width=50%>
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called **embeddings**. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# <img src='assets/lookup_matrix.png' width=50%>
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=50%>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ---
# ## Word2Vec
#
# The Word2Vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words.
#
# <img src="assets/context_drink.png" width=40%>
#
# Words that show up in similar **contexts**, such as "coffee", "tea", and "water" will have vectors near each other. Different words will be further away from one another, and relationships can be represented by distance in vector space.
#
# <img src="assets/vector_distance.png" width=40%>
#
#
# There are two architectures for implementing Word2Vec:
# >* CBOW (Continuous Bag-Of-Words) and
# * Skip-gram
#
# <img src="assets/word2vec_architectures.png" width=60%>
#
# In this implementation, we'll be using the **skip-gram architecture** because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.

# %% [markdown]
# ---
# ## Loading Data
#
# Next, we'll ask you to load in data and place it in the `data` directory
#
# 1. Load the [text8 dataset](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/October/5bbe6499_text8/text8.zip); a file of cleaned up *Wikipedia article text* from Matt Mahoney.
# 2. Place that data in the `data` folder in the home directory.
# 3. Then you can extract it and delete the archive, zip file to save storage space.
#
# After following these steps, you should have one file in your data directory: `data/text8`.

# %%
# read in the extracted text file      
with open('data/text8') as f:
    text = f.read()

# print out the first 100 characters
print(text[:100])

# %% [markdown]
# ## Pre-processing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils.py` file. The `preprocess` function does a few things:
# >* It converts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems.
# * It removes all words that show up five or *fewer* times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations.
# * It returns a list of words in the text.
#
# This may take a few seconds to run, since our text file is quite large. If you want to write your own functions for this stuff, go for it!

# %%
import utils

# get list of words
words = utils.preprocess(text)
print(words[:30])

# %%
# print some stats about this word data
print("Total words in text: {}".format(len(words)))
print("Unique words: {}".format(len(set(words)))) # `set` removes any duplicate words

# %% [markdown]
# ### Dictionaries
#
# Next, I'm creating two dictionaries to convert words to integers and back again (integers to words). This is again done with a function in the `utils.py` file. `create_lookup_tables` takes in a list of words in a text and returns two dictionaries.
# >* The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1, and so on.
#
# Once we have our dictionaries, the words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

print(int_words[:30])

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# $$ P(0) = 1 - \sqrt{\frac{1*10^{-5}}{1*10^6/16*10^6}} = 0.98735 $$
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import math 
from collections import Counter
import random
import numpy as np
threshold = 1e-5
word_counts = Counter(int_words)
def probability_of_discarding(index):
    global word_counts
    frequency_of_occurence = word_counts[index]/len(word_counts)  
    p = 1-math.sqrt(threshold/frequency_of_occurence)
    return p

# %%
#print(list(word_counts.items())[0])  # dictionary of int_words, how many times they appear

total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
# discard some frequent words, according to the subsampling equation
# create a new list of words for training
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

print(train_words[:30])

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to define a surrounding _context_ and grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $[ 1: C ]$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.
#
# Say, we have an input and we're interested in the idx=2 token, `741`:
# ```
# [5233, 58, 741, 10571, 27349, 0, 15067, 58112, 3580, 58, 10712]
# ```
#
# For `R=2`, `get_target` should return a list of four values:
# ```
# [5233, 58, 10571, 27349]
# ```

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = random.randint(1,window_size)
    up_R = R
    
    if( idx - R > 0 ):
        min = idx-R
      
    else:
        min = 0
        up_R += idx-R
        
    if (idx + R > len(words)):
        max = len(words)
    else:
        max = idx + R + 1
    
    r = words[min:max]
    r.pop(up_R)
    
    #print("R is "+str(R)+" Corrected R is "+str(up_R)+" The index is "+str(idx))
    # implement this function
    
    return r

# %%
# test your code!

# run this cell multiple times to check for random window selection
int_text = [i for i in range(10)]
print('Input: ', int_text)
idx=5 # word index of interest

target = get_target(int_text, idx=idx, window_size=5)
print('Target: ', target)  # you should get some indices around the idx

# %% [markdown]
# ### Generating Batches
#
# Here's a generator function that returns batches of input and target data for our model, using the `get_target` function from above. The idea is that it grabs `batch_size` words from a words list. Then for each of those batches, it gets the target words in a window.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    
    #Looping one batch at a time
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
int_text = [i for i in range(20)]
x,y = next(get_batches(int_text, batch_size=4, window_size=5))

print('x\n', x)
print('y\n', y)

# %% [markdown]
# ## Building the graph
#
# Below is an approximate diagram of the general structure of our network.
# <img src="assets/skip_gram_net_arch.png" width=60%>
#
# >* The input words are passed in as batches of input word tokens.
# * This will go into a hidden layer of linear units (our embedding layer).
# * Then, finally into a softmax output layer.
#
# We'll use the softmax layer to make a prediction about the context words by sampling, as usual.
#
# The idea here is to train the embedding layer weight matrix to find efficient representations for our words. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in _other_ networks we build using this dataset.

# %% [markdown]
# ---
# ## Validation
#
# Here, I'm creating a function that will help us observe our model as it learns. We're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them using the cosine similarity:
#
# $$
# \mathrm{similarity} = \cos(\theta) = \frac{\vec{a} \cdot \vec{b}}{|\vec{a}||\vec{b}|}
# $$
#
#
# We can encode the validation words as vectors $\vec{a}$ using the embedding table, then calculate the similarity with each word vector $\vec{b}$ in the embedding table. With the similarities, we can print out the validation words and words in our embedding table semantically similar to those words. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
def cosine_similarity(embedding, valid_size=16, valid_window=100, device='cpu'):
    """ Returns the cosine similarity of validation words with words in the embedding matrix.
        Here, embedding should be a PyTorch embedding module.
    """
    
    # Here we're calculating the cosine similarity between some random words and 
    # our embedding vectors. With the similarities, we can look at what words are
    # close to our random words.
    
    # sim = (a . b) / |a||b|
    
    embed_vectors = embedding.weight
    
    # magnitude of embedding vectors, |b|
    magnitudes = embed_vectors.pow(2).sum(dim=1).sqrt().unsqueeze(0)
    
    # pick N words from our ranges (0,window) and (1000,1000+window). lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,
                               random.sample(range(1000,1000+valid_window), valid_size//2))
    valid_examples = torch.LongTensor(valid_examples).to(device)
    
    valid_vectors = embedding(valid_examples)
    similarities = torch.mm(valid_vectors, embed_vectors.t())/magnitudes
        
    return valid_examples, similarities

# %% [markdown]
# ## SkipGram model
#
# Define and train the SkipGram model.
# > You'll need to define an [embedding layer](https://pytorch.org/docs/stable/nn.html#embedding) and a final, softmax output layer.
#
# An Embedding layer takes in a number of inputs, importantly:
# * **num_embeddings** – the size of the dictionary of embeddings, or how many rows you'll want in the embedding weight matrix
# * **embedding_dim** – the size of each embedding vector; the embedding dimension

# %%
import torch
from torch import nn
import torch.optim as optim

# %%
class SkipGram(nn.Module):
    def __init__(self, n_vocab, n_embed):
        super().__init__()
        
        self.embed = nn.Embedding(n_vocab, n_embed)
        self.output = nn.Linear(n_embed, n_vocab)
        
        self.log_softmax = nn.LogSoftmax(dim=1)
    
    def forward(self, x):
        
        x=self.embed(x)
        x=self.output(x)
        x = self.log_softmax(x)
        
        return x

# %% [markdown]
# ### Training
#
# Below is our training loop, and I recommend that you train on GPU, if available.
#
# **Note that, because we applied a softmax function to our model output, we are using NLLLoss** as opposed to cross entropy. This is because Softmax  in combination with NLLLoss = CrossEntropy loss .

# %%
# check if GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'

embedding_dim=300 # you can change, if you want

model = SkipGram(len(vocab_to_int), embedding_dim).to(device)
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

print_every = 500
steps = 0
epochs = 5

# train for some number of epochs
for e in range(epochs):
    
    # get input and target batches
    for inputs, targets in get_batches(train_words, 512):
        print(inputs)
        steps += 1
        inputs, targets = torch.LongTensor(inputs), torch.LongTensor(targets)
        inputs, targets = inputs.to(device), targets.to(device)
        
        log_ps = model(inputs)
        loss = criterion(log_ps, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if steps % print_every == 0:                  
            # getting examples and similarities      
            valid_examples, valid_similarities = cosine_similarity(model.embed, device=device)
            _, closest_idxs = valid_similarities.topk(6) # topk highest similarities
            
            valid_examples, closest_idxs = valid_examples.to('cpu'), closest_idxs.to('cpu')
            for ii, valid_idx in enumerate(valid_examples):
                closest_words = [int_to_vocab[idx.item()] for idx in closest_idxs[ii]][1:]
                print(int_to_vocab[valid_idx.item()] + " | " + ', '.join(closest_words))
            print("...")
# Out:
# R is 5 Corrected R is 0 The index is 0
# R is 1 Corrected R is 1 The index is 1
# R is 5 Corrected R is 2 The index is 2
# R is 3 Corrected R is 3 The index is 3
# R is 5 Corrected R is 4 The index is 4
# R is 3 Corrected R is 3 The index is 5
# R is 2 Corrected R is 2 The index is 6
# R is 5 Corrected R is 5 The index is 7
# R is 4 Corrected R is 4 The index is 8
# R is 5 Corrected R is 5 The index is 9
# R is 5 Corrected R is 5 The index is 10
# R is 2 Corrected R is 2 The index is 11
# R is 1 Corrected R is 1 The index is 12
# R is 4 Corrected R is 4 The index is 13
# R is 1 Corrected R is 1 The index is 14
# R is 5 Corrected R is 5 The index is 15
# R is 1 Corrected R is 1 The index is 16
# R is 4 Corrected R is 4 The index is 17
# R is 5 Corrected R is 5 The index is 18
# R is 4 Corrected R is 4 The index is 19
# R is 2 Corrected R is 2 The index is 20
# R is 2 Corrected R is 2 The index is 21
# R is 4 Corrected R is 4 The index is 22
# R is 4 Corrected R is 4 The index is 23
# R is 3 Corrected R is 3 The index is 24
# R is 5 Corrected R is 5 The index is 25
# R is 2 Corrected R is 2 The index is 26
# R is 2 Corrected R is 2 The index is 27
# R is 2 Corrected R is 2 The index is 28
# R is 4 Corrected R is 4 The index is 29
# R is 3 Corrected R is 3 The index is 30
# R is 5 Corrected R is 5 The index is 31
# R is 3 Corrected R is 3 The index is 32
# R is 4 Corrected R is 4 The index is 33
# R is 5 Corrected R is 5 The index is 34
# R is 4 Corrected R is 4 The index is 35
# R is 2 Corrected R is 2 The index is 36
# R is 4 Corrected R is 4 The index is 37
# R is 3 Corrected R is 3 The index is 38
# R is 3 Corrected R is 3 The index is 39
# R is 5 Corrected R is 5 The index is 40
# R is 4 Corrected R is 4 The index is 41
# R is 1 Corrected R is 1 The index is 42
# R is 4 Corrected R is 4 The index is 43
# R is 5 Corrected R is 5 The index is 44
# R is 1 Corrected R is 1 The index is 45
# R is 3 Corrected R is 3 The index is 46
# R is 2 Corrected R is 2 The index is 47
# R is 3 Corrected R is 3 The index is 48
# R is 5 Corrected R is 5 The index is 49
# R is 3 Corrected R is 3 The index is 50
# R is 1 Corrected R is 1 The index is 51
# R is 3 Corrected R is 3 The index is 52
# R is 1 Corrected R is 1 The index is 53
# R is 3 Corrected R is 3 The index is 54
# R is 2 Corrected R is 2 The index is 55
# R is 4 Corrected R is 4 The index is 56
# R is 1 Corrected R is 1 The index is 57
# R is 2 Corrected R is 2 The index is 58
# R is 2 Corrected R is 2 The index is 59
# R is 1 Corrected R is 1 The index is 60
# R is 1 Corrected R is 1 The index is 61
# R is 4 Corrected R is 4 The index is 62
# R is 3 Corrected R is 3 The index is 63
# R is 5 Corrected R is 5 The index is 64
# R is 2 Corrected R is 2 The index is 65
# R is 1 Corrected R is 1 The index is 66
# R is 5 Corrected R is 5 The index is 67
# R is 5 Corrected R is 5 The index is 68
# R is 2 Corrected R is 2 The index is 69
# R is 1 Corrected R is 1 The index is 70
# R is 1 Corrected R is 1 The index is 71
# R is 2 Corrected R is 2 The index is 72
# R is 2 Corrected R is 2 The index is 73
# R is 3 Corrected R is 3 The index is 74
# R is 1 Corrected R is 1 The index is 75
# R is 1 Corrected R is 1 The index is 76
# R is 2 Corrected R is 2 The index is 77
# R is 3 Corrected R is 3 The index is 78
# R is 4 Corrected R is 4 The index is 79
# R is 2 Corrected R is 2 The index is 80
# R is 1 Corrected R is 1 The index is 81
# R is 1 Corrected R is 1 The index is 82
# R is 4 Corrected R is 4 The index is 83
# R is 3 Corrected R is 3 The index is 84
# R is 3 Corrected R is 3 The index is 85
# R is 4 Corrected R is 4 The index is 86
# R is 4 Corrected R is 4 The index is 87
# R is 2 Corrected R is 2 The index is 88
# R is 4 Corrected R is 4 The index is 89
# R is 1 Corrected R is 1 The index is 90
# R is 2 Corrected R is 2 The index is 91
# R is 2 Corrected R is 2 The index is 92
# R is 3 Corrected R is 3 The index is 93
# R is 1 Corrected R is 1 The index is 94
# R is 1 Corrected R is 1 The index is 95
# R is 5 Corrected R is 5 The index is 96
# R is 3 Corrected R is 3 The index is 97
# R is 5 Corrected R is 5 The index is 98
# R is 3 Corrected R is 3 The index is 99
# R is 5 Corrected R is 5 The index is 100
# R is 5 Corrected R is 5 The index is 101
# R is 4 Corrected R is 4 The index is 102
# R is 4 Corrected R is 4 The index is 103
# R is 5 Corrected R is 5 The index is 104
# R is 5 Corrected R is 5 The index is 105
# R is 2 Corrected R is 2 The index is 106
# R is 1 Corrected R is 1 The index is 107
# R is 4 Corrected R is 4 The index is 108
# R is 4 Corrected R is 4 The index is 109
# R is 4 Corrected R is 4 The index is 110
# R is 1 Corrected R is 1 The index is 111
# R is 5 Corrected R is 5 The index is 112
# R is 1 Corrected R is 1 The index is 113
# R is 2 Corrected R is 2 The index is 114
# R is 2 Corrected R is 2 The index is 115
# R is 1 Corrected R is 1 The index is 116
# R is 4 Corrected R is 4 The index is 117
# R is 5 Corrected R is 5 The index is 118
# R is 3 Corrected R is 3 The index is 119
# R is 3 Corrected R is 3 The index is 120
# R is 3 Corrected R is 3 The index is 121
# R is 1 Corrected R is 1 The index is 122
# R is 4 Corrected R is 4 The index is 123
# R is 4 Corrected R is 4 The index is 124
# R is 3 Corrected R is 3 The index is 125
# R is 5 Corrected R is 5 The index is 126
# R is 2 Corrected R is 2 The index is 127
# R is 1 Corrected R is 1 The index is 128
# R is 2 Corrected R is 2 The index is 129
# R is 4 Corrected R is 4 The index is 130
# R is 4 Corrected R is 4 The index is 131
# R is 5 Corrected R is 5 The index is 132
# R is 5 Corrected R is 5 The index is 133
# R is 4 Corrected R is 4 The index is 134
# R is 4 Corrected R is 4 The index is 135
# R is 2 Corrected R is 2 The index is 136
# R is 5 Corrected R is 5 The index is 137
# R is 4 Corrected R is 4 The index is 138
# R is 2 Corrected R is 2 The index is 139
# R is 4 Corrected R is 4 The index is 140
# R is 5 Corrected R is 5 The index is 141
# R is 3 Corrected R is 3 The index is 142
# R is 5 Corrected R is 5 The index is 143
# R is 3 Corrected R is 3 The index is 144
# R is 3 Corrected R is 3 The index is 145
# R is 3 Corrected R is 3 The index is 146
# R is 2 Corrected R is 2 The index is 147
# R is 5 Corrected R is 5 The index is 148
# R is 2 Corrected R is 2 The index is 149
# R is 2 Corrected R is 2 The index is 150
# R is 1 Corrected R is 1 The index is 151
# R is 5 Corrected R is 5 The index is 152
# R is 4 Corrected R is 4 The index is 153
# R is 3 Corrected R is 3 The index is 154
# R is 5 Corrected R is 5 The index is 155
# R is 1 Corrected R is 1 The index is 156
# R is 5 Corrected R is 5 The index is 157
# R is 2 Corrected R is 2 The index is 158
# R is 2 Corrected R is 2 The index is 159
# R is 5 Corrected R is 5 The index is 160
# R is 2 Corrected R is 2 The index is 161
# R is 2 Corrected R is 2 The index is 162
# R is 3 Corrected R is 3 The index is 163
# R is 3 Corrected R is 3 The index is 164
# R is 4 Corrected R is 4 The index is 165
# R is 5 Corrected R is 5 The index is 166
# R is 1 Corrected R is 1 The index is 167
# R is 2 Corrected R is 2 The index is 168
# R is 1 Corrected R is 1 The index is 169
# R is 3 Corrected R is 3 The index is 170
# R is 3 Corrected R is 3 The index is 171
# R is 1 Corrected R is 1 The index is 172
# R is 1 Corrected R is 1 The index is 173
# R is 4 Corrected R is 4 The index is 174
# R is 2 Corrected R is 2 The index is 175
# R is 4 Corrected R is 4 The index is 176
# R is 5 Corrected R is 5 The index is 177
# R is 4 Corrected R is 4 The index is 178
# R is 1 Corrected R is 1 The index is 179
# R is 3 Corrected R is 3 The index is 180
# R is 2 Corrected R is 2 The index is 181
# R is 3 Corrected R is 3 The index is 182
# R is 1 Corrected R is 1 The index is 183
# R is 1 Corrected R is 1 The index is 184
# R is 1 Corrected R is 1 The index is 185
# R is 5 Corrected R is 5 The index is 186
# R is 3 Corrected R is 3 The index is 187
# R is 5 Corrected R is 5 The index is 188
# R is 5 Corrected R is 5 The index is 189
# R is 5 Corrected R is 5 The index is 190
# R is 5 Corrected R is 5 The index is 191
# R is 3 Corrected R is 3 The index is 192
# R is 1 Corrected R is 1 The index is 193
# R is 1 Corrected R is 1 The index is 194
# R is 5 Corrected R is 5 The index is 195
# R is 2 Corrected R is 2 The index is 196
# R is 4 Corrected R is 4 The index is 197
# R is 1 Corrected R is 1 The index is 198
# R is 4 Corrected R is 4 The index is 199
# R is 5 Corrected R is 5 The index is 200
# R is 2 Corrected R is 2 The index is 201
# R is 4 Corrected R is 4 The index is 202
# R is 2 Corrected R is 2 The index is 203
# R is 5 Corrected R is 5 The index is 204
# R is 1 Corrected R is 1 The index is 205
# R is 2 Corrected R is 2 The index is 206
# R is 3 Corrected R is 3 The index is 207
# R is 5 Corrected R is 5 The index is 208
# R is 3 Corrected R is 3 The index is 209
# R is 3 Corrected R is 3 The index is 210
# R is 4 Corrected R is 4 The index is 211
# R is 1 Corrected R is 1 The index is 212
# R is 4 Corrected R is 4 The index is 213
# R is 4 Corrected R is 4 The index is 214
# R is 4 Corrected R is 4 The index is 215
# R is 4 Corrected R is 4 The index is 216
# R is 3 Corrected R is 3 The index is 217
# R is 1 Corrected R is 1 The index is 218
# R is 5 Corrected R is 5 The index is 219
# R is 1 Corrected R is 1 The index is 220
# R is 1 Corrected R is 1 The index is 221
# R is 1 Corrected R is 1 The index is 222
# R is 4 Corrected R is 4 The index is 223
# R is 5 Corrected R is 5 The index is 224
# R is 4 Corrected R is 4 The index is 225
# R is 3 Corrected R is 3 The index is 226
# R is 2 Corrected R is 2 The index is 227
# R is 5 Corrected R is 5 The index is 228
# R is 1 Corrected R is 1 The index is 229
# R is 2 Corrected R is 2 The index is 230
# R is 5 Corrected R is 5 The index is 231
# R is 2 Corrected R is 2 The index is 232
# R is 4 Corrected R is 4 The index is 233
# R is 5 Corrected R is 5 The index is 234
# R is 1 Corrected R is 1 The index is 235
# R is 1 Corrected R is 1 The index is 236
# R is 5 Corrected R is 5 The index is 237
# R is 4 Corrected R is 4 The index is 238
# R is 4 Corrected R is 4 The index is 239
# R is 3 Corrected R is 3 The index is 240
# R is 3 Corrected R is 3 The index is 241
# R is 1 Corrected R is 1 The index is 242
# R is 4 Corrected R is 4 The index is 243
# R is 3 Corrected R is 3 The index is 244
# R is 3 Corrected R is 3 The index is 245
# R is 1 Corrected R is 1 The index is 246
# R is 3 Corrected R is 3 The index is 247
# R is 1 Corrected R is 1 The index is 248
# R is 1 Corrected R is 1 The index is 249
# R is 5 Corrected R is 5 The index is 250
# R is 4 Corrected R is 4 The index is 251
# R is 1 Corrected R is 1 The index is 252
# R is 1 Corrected R is 1 The index is 253
# R is 5 Corrected R is 5 The index is 254
# R is 1 Corrected R is 1 The index is 255
# R is 5 Corrected R is 5 The index is 256
# R is 4 Corrected R is 4 The index is 257
# R is 4 Corrected R is 4 The index is 258
# R is 2 Corrected R is 2 The index is 259
# R is 3 Corrected R is 3 The index is 260
# R is 1 Corrected R is 1 The index is 261
# R is 5 Corrected R is 5 The index is 262
# R is 5 Corrected R is 5 The index is 263
# R is 2 Corrected R is 2 The index is 264
# R is 1 Corrected R is 1 The index is 265
# R is 1 Corrected R is 1 The index is 266
# R is 2 Corrected R is 2 The index is 267
# R is 3 Corrected R is 3 The index is 268
# R is 3 Corrected R is 3 The index is 269
# R is 5 Corrected R is 5 The index is 270
# R is 1 Corrected R is 1 The index is 271
# R is 1 Corrected R is 1 The index is 272
# R is 2 Corrected R is 2 The index is 273
# R is 1 Corrected R is 1 The index is 274
# R is 4 Corrected R is 4 The index is 275
# R is 1 Corrected R is 1 The index is 276
# R is 4 Corrected R is 4 The index is 277
# R is 1 Corrected R is 1 The index is 278
# R is 5 Corrected R is 5 The index is 279
# R is 2 Corrected R is 2 The index is 280
# R is 2 Corrected R is 2 The index is 281
# R is 1 Corrected R is 1 The index is 282
# R is 4 Corrected R is 4 The index is 283
# R is 4 Corrected R is 4 The index is 284
# R is 1 Corrected R is 1 The index is 285
# R is 3 Corrected R is 3 The index is 286
# R is 1 Corrected R is 1 The index is 287
# R is 3 Corrected R is 3 The index is 288
# R is 2 Corrected R is 2 The index is 289
# R is 5 Corrected R is 5 The index is 290
# R is 3 Corrected R is 3 The index is 291
# R is 5 Corrected R is 5 The index is 292
# R is 3 Corrected R is 3 The index is 293
# R is 4 Corrected R is 4 The index is 294
# R is 2 Corrected R is 2 The index is 295
# R is 3 Corrected R is 3 The index is 296
# R is 4 Corrected R is 4 The index is 297
# R is 2 Corrected R is 2 The index is 298
# R is 3 Corrected R is 3 The index is 299
# R is 5 Corrected R is 5 The index is 300
# R is 5 Corrected R is 5 The index is 301
# R is 3 Corrected R is 3 The index is 302
# R is 4 Corrected R is 4 The index is 303
# R is 4 Corrected R is 4 The index is 304
# R is 1 Corrected R is 1 The index is 305
# R is 4 Corrected R is 4 The index is 306
# R is 2 Corrected R is 2 The index is 307
# R is 1 Corrected R is 1 The index is 308
# R is 3 Corrected R is 3 The index is 309
# R is 5 Corrected R is 5 The index is 310
# R is 1 Corrected R is 1 The index is 311
# R is 4 Corrected R is 4 The index is 312
# R is 5 Corrected R is 5 The index is 313
# R is 2 Corrected R is 2 The index is 314
# R is 5 Corrected R is 5 The index is 315
# R is 5 Corrected R is 5 The index is 316
# R is 2 Corrected R is 2 The index is 317
# R is 3 Corrected R is 3 The index is 318
# R is 2 Corrected R is 2 The index is 319
# R is 1 Corrected R is 1 The index is 320
# R is 3 Corrected R is 3 The index is 321
# R is 5 Corrected R is 5 The index is 322
# R is 5 Corrected R is 5 The index is 323
# R is 3 Corrected R is 3 The index is 324
# R is 3 Corrected R is 3 The index is 325
# R is 1 Corrected R is 1 The index is 326
# R is 4 Corrected R is 4 The index is 327
# R is 1 Corrected R is 1 The index is 328
# R is 5 Corrected R is 5 The index is 329
# R is 5 Corrected R is 5 The index is 330
# R is 5 Corrected R is 5 The index is 331
# R is 3 Corrected R is 3 The index is 332
# R is 3 Corrected R is 3 The index is 333
# R is 5 Corrected R is 5 The index is 334
# R is 5 Corrected R is 5 The index is 335
# R is 3 Corrected R is 3 The index is 336
# R is 1 Corrected R is 1 The index is 337
# R is 2 Corrected R is 2 The index is 338
# R is 2 Corrected R is 2 The index is 339
# R is 2 Corrected R is 2 The index is 340
# R is 4 Corrected R is 4 The index is 341
# R is 2 Corrected R is 2 The index is 342
# R is 5 Corrected R is 5 The index is 343
# R is 1 Corrected R is 1 The index is 344
# R is 1 Corrected R is 1 The index is 345
# R is 3 Corrected R is 3 The index is 346
# R is 5 Corrected R is 5 The index is 347
# R is 5 Corrected R is 5 The index is 348
# R is 4 Corrected R is 4 The index is 349
# R is 4 Corrected R is 4 The index is 350
# R is 2 Corrected R is 2 The index is 351
# R is 1 Corrected R is 1 The index is 352
# R is 1 Corrected R is 1 The index is 353
# R is 3 Corrected R is 3 The index is 354
# R is 1 Corrected R is 1 The index is 355
# R is 4 Corrected R is 4 The index is 356
# R is 2 Corrected R is 2 The index is 357
# R is 4 Corrected R is 4 The index is 358
# R is 4 Corrected R is 4 The index is 359
# R is 1 Corrected R is 1 The index is 360
# R is 3 Corrected R is 3 The index is 361
# R is 2 Corrected R is 2 The index is 362
# R is 1 Corrected R is 1 The index is 363
# R is 1 Corrected R is 1 The index is 364
# R is 3 Corrected R is 3 The index is 365
# R is 1 Corrected R is 1 The index is 366
# R is 1 Corrected R is 1 The index is 367
# R is 5 Corrected R is 5 The index is 368
# R is 5 Corrected R is 5 The index is 369
# R is 5 Corrected R is 5 The index is 370
# R is 3 Corrected R is 3 The index is 371
# R is 1 Corrected R is 1 The index is 372
# R is 1 Corrected R is 1 The index is 373
# R is 2 Corrected R is 2 The index is 374
# R is 2 Corrected R is 2 The index is 375
# R is 2 Corrected R is 2 The index is 376
# R is 1 Corrected R is 1 The index is 377
# R is 4 Corrected R is 4 The index is 378
# R is 4 Corrected R is 4 The index is 379
# R is 2 Corrected R is 2 The index is 380
# R is 3 Corrected R is 3 The index is 381
# R is 3 Corrected R is 3 The index is 382
# R is 3 Corrected R is 3 The index is 383
# R is 5 Corrected R is 5 The index is 384
# R is 3 Corrected R is 3 The index is 385
# R is 3 Corrected R is 3 The index is 386
# R is 3 Corrected R is 3 The index is 387
# R is 3 Corrected R is 3 The index is 388
# R is 3 Corrected R is 3 The index is 389
# R is 5 Corrected R is 5 The index is 390
# R is 1 Corrected R is 1 The index is 391
# R is 5 Corrected R is 5 The index is 392
# R is 1 Corrected R is 1 The index is 393
# R is 4 Corrected R is 4 The index is 394
# R is 4 Corrected R is 4 The index is 395
# R is 5 Corrected R is 5 The index is 396
# R is 5 Corrected R is 5 The index is 397
# R is 1 Corrected R is 1 The index is 398
# R is 2 Corrected R is 2 The index is 399
# R is 3 Corrected R is 3 The index is 400
# R is 5 Corrected R is 5 The index is 401
# R is 2 Corrected R is 2 The index is 402
# R is 4 Corrected R is 4 The index is 403
# R is 3 Corrected R is 3 The index is 404
# R is 5 Corrected R is 5 The index is 405
# R is 2 Corrected R is 2 The index is 406
# R is 2 Corrected R is 2 The index is 407
# R is 1 Corrected R is 1 The index is 408
# R is 3 Corrected R is 3 The index is 409
# R is 4 Corrected R is 4 The index is 410
# R is 5 Corrected R is 5 The index is 411
# R is 2 Corrected R is 2 The index is 412
# R is 3 Corrected R is 3 The index is 413
# R is 4 Corrected R is 4 The index is 414
# R is 3 Corrected R is 3 The index is 415
# R is 5 Corrected R is 5 The index is 416
# R is 3 Corrected R is 3 The index is 417
# R is 2 Corrected R is 2 The index is 418
# R is 2 Corrected R is 2 The index is 419
# R is 3 Corrected R is 3 The index is 420
# R is 4 Corrected R is 4 The index is 421
# R is 1 Corrected R is 1 The index is 422
# R is 3 Corrected R is 3 The index is 423
# R is 5 Corrected R is 5 The index is 424
# R is 4 Corrected R is 4 The index is 425
# R is 3 Corrected R is 3 The index is 426
# R is 1 Corrected R is 1 The index is 427
# R is 1 Corrected R is 1 The index is 428
# R is 5 Corrected R is 5 The index is 429
# R is 2 Corrected R is 2 The index is 430
# R is 5 Corrected R is 5 The index is 431
# R is 5 Corrected R is 5 The index is 432
# R is 5 Corrected R is 5 The index is 433
# R is 2 Corrected R is 2 The index is 434
# R is 4 Corrected R is 4 The index is 435
# R is 2 Corrected R is 2 The index is 436
# R is 1 Corrected R is 1 The index is 437
# R is 3 Corrected R is 3 The index is 438
# R is 2 Corrected R is 2 The index is 439
# R is 5 Corrected R is 5 The index is 440
# R is 3 Corrected R is 3 The index is 441
# R is 2 Corrected R is 2 The index is 442
# R is 1 Corrected R is 1 The index is 443
# R is 2 Corrected R is 2 The index is 444
# R is 2 Corrected R is 2 The index is 445
# R is 5 Corrected R is 5 The index is 446
# R is 3 Corrected R is 3 The index is 447
# R is 2 Corrected R is 2 The index is 448
# R is 4 Corrected R is 4 The index is 449
# R is 5 Corrected R is 5 The index is 450
# R is 2 Corrected R is 2 The index is 451
# R is 5 Corrected R is 5 The index is 452
# R is 5 Corrected R is 5 The index is 453
# R is 1 Corrected R is 1 The index is 454
# R is 3 Corrected R is 3 The index is 455
# R is 4 Corrected R is 4 The index is 456
# R is 1 Corrected R is 1 The index is 457
# R is 4 Corrected R is 4 The index is 458
# R is 4 Corrected R is 4 The index is 459
# R is 5 Corrected R is 5 The index is 460
# R is 2 Corrected R is 2 The index is 461
# R is 5 Corrected R is 5 The index is 462
# R is 1 Corrected R is 1 The index is 463
# R is 5 Corrected R is 5 The index is 464
# R is 1 Corrected R is 1 The index is 465
# R is 2 Corrected R is 2 The index is 466
# R is 5 Corrected R is 5 The index is 467
# R is 2 Corrected R is 2 The index is 468
# R is 3 Corrected R is 3 The index is 469
# R is 2 Corrected R is 2 The index is 470
# R is 1 Corrected R is 1 The index is 471
# R is 4 Corrected R is 4 The index is 472
# R is 1 Corrected R is 1 The index is 473
# R is 4 Corrected R is 4 The index is 474
# R is 3 Corrected R is 3 The index is 475
# R is 4 Corrected R is 4 The index is 476
# R is 5 Corrected R is 5 The index is 477
# R is 1 Corrected R is 1 The index is 478
# R is 2 Corrected R is 2 The index is 479
# R is 2 Corrected R is 2 The index is 480
# R is 1 Corrected R is 1 The index is 481
# R is 2 Corrected R is 2 The index is 482
# R is 3 Corrected R is 3 The index is 483
# R is 3 Corrected R is 3 The index is 484
# R is 1 Corrected R is 1 The index is 485
# R is 1 Corrected R is 1 The index is 486
# R is 3 Corrected R is 3 The index is 487
# R is 3 Corrected R is 3 The index is 488
# R is 1 Corrected R is 1 The index is 489
# R is 3 Corrected R is 3 The index is 490
# R is 5 Corrected R is 5 The index is 491
# R is 4 Corrected R is 4 The index is 492
# R is 4 Corrected R is 4 The index is 493
# R is 5 Corrected R is 5 The index is 494
# R is 3 Corrected R is 3 The index is 495
# R is 2 Corrected R is 2 The index is 496
# R is 1 Corrected R is 1 The index is 497
# R is 1 Corrected R is 1 The index is 498
# R is 3 Corrected R is 3 The index is 499
# R is 3 Corrected R is 3 The index is 500
# R is 5 Corrected R is 5 The index is 501
# R is 1 Corrected R is 1 The index is 502
# R is 3 Corrected R is 3 The index is 503
# R is 3 Corrected R is 3 The index is 504
# R is 2 Corrected R is 2 The index is 505
# R is 1 Corrected R is 1 The index is 506
# R is 4 Corrected R is 4 The index is 507
# R is 4 Corrected R is 4 The index is 508
# R is 2 Corrected R is 2 The index is 509
# R is 2 Corrected R is 2 The index is 510
# R is 4 Corrected R is 4 The index is 511
# [5233, 5233, 5233, 5233, 5233, 3080, 3080, 3133, 3133, 3133, 3133, 3133, 3133, 3133, 155, 155, 155, 155, 155, 155, 476, 476, 476, 476, 476, 476, 476, 476, 476, 10571, 10571, 10571, 10571, 10571, 10571, 27349, 27349, 27349, 27349, 15067, 15067, 15067, 15067, 15067, 15067, 15067, 15067, 15067, 15067, 58112, 58112, 58112, 58112, 58112, 58112, 58112, 58112, 854, 854, 854, 854, 854, 854, 854, 854, 854, 854, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 10712, 10712, 10712, 10712, 2731, 2731, 371, 371, 371, 371, 371, 371, 371, 371, 40, 40, 1423, 1423, 1423, 1423, 1423, 1423, 1423, 1423, 1423, 1423, 2757, 2757, 686, 686, 686, 686, 686, 686, 686, 686, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 44611, 44611, 44611, 44611, 44611, 44611, 44611, 44611, 2877, 2877, 2877, 2877, 186, 186, 186, 186, 5233, 5233, 5233, 5233, 5233, 5233, 5233, 5233, 2621, 2621, 2621, 2621, 2621, 2621, 2621, 2621, 8983, 8983, 8983, 8983, 8983, 8983, 4147, 4147, 4147, 4147, 4147, 4147, 4147, 4147, 4147, 4147, 4186, 4186, 4186, 4186, 5233, 5233, 5233, 5233, 4860, 4860, 4860, 4860, 6753, 6753, 6753, 6753, 6753, 6753, 6753, 6753, 7573, 7573, 7573, 7573, 7573, 7573, 11064, 11064, 11064, 11064, 11064, 11064, 11064, 11064, 11064, 11064, 7088, 7088, 7088, 7088, 7088, 7088, 5948, 5948, 5948, 5948, 5948, 5948, 5948, 5948, 4861, 4861, 4861, 4861, 4861, 4861, 4861, 4861, 4861, 4861, 20299, 20299, 20299, 20299, 20299, 20299, 20299, 20299, 53721, 53721, 53721, 53721, 5, 5, 5, 5, 5, 5, 5, 5, 25636, 25636, 25636, 25636, 25636, 25636, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 7573, 15200, 15200, 15200, 15200, 15200, 15200, 15200, 15200, 332, 332, 1774, 1774, 1774, 1774, 1774, 1774, 1774, 1774, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 4860, 4860, 344, 344, 344, 344, 344, 344, 5690, 5690, 5690, 5690, 755, 755, 755, 755, 755, 755, 4105, 4105, 4105, 4105, 4105, 4105, 4105, 4105, 4105, 4105, 4331, 4331, 4331, 4331, 4331, 4331, 567, 567, 8117, 8117, 8117, 8117, 8117, 8117, 5233, 5233, 7088, 7088, 7088, 7088, 7088, 7088, 1423, 1423, 1423, 1423, 8174, 8174, 8174, 8174, 8174, 8174, 8174, 8174, 4778, 4778, 364, 364, 364, 364, 8399, 8399, 8399, 8399, 8040, 8040, 24172, 24172, 1693, 1693, 1693, 1693, 1693, 1693, 1693, 1693, 151, 151, 151, 151, 151, 151, 4778, 4778, 4778, 4778, 4778, 4778, 4778, 4778, 4778, 4778, 8118, 8118, 8118, 8118, 1465, 1465, 24172, 24172, 24172, 24172, 24172, 24172, 24172, 24172, 24172, 24172, 12743, 12743, 12743, 12743, 12743, 12743, 12743, 12743, 12743, 12743, 6130, 6130, 6130, 6130, 4187, 4187, 21148, 21148, 16455, 16455, 16455, 16455, 7239, 7239, 7239, 7239, 1193, 1193, 1193, 1193, 1193, 1193, 10207, 10207, 2514, 2514, 15068, 15068, 15068, 15068, 12297, 12297, 12297, 12297, 12297, 12297, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 7088, 133, 133, 133, 133, 11064, 11064, 3055, 3055, 12060, 12060, 12060, 12060, 12060, 12060, 12060, 12060, 734, 734, 734, 734, 734, 734, 4778, 4778, 4778, 4778, 4778, 4778, 6598, 6598, 6598, 6598, 6598, 6598, 6598, 6598, 14622, 14622, 14622, 14622, 14622, 14622, 14622, 14622, 27, 27, 27, 27, 24172, 24172, 24172, 24172, 24172, 24172, 24172, 24172, 20027, 20027, 20300, 20300, 20300, 20300, 53722, 53722, 53722, 53722, 24172, 24172, 24172, 24172, 24172, 24172, 20300, 20300, 16456, 16456, 30106, 30106, 30106, 30106, 30106, 30106, 30106, 30106, 30106, 30106, 3832, 3832, 3832, 3832, 3832, 3832, 53723, 53723, 53723, 53723, 53723, 53723, 53723, 53723, 53723, 53723, 3807, 3807, 3807, 3807, 3807, 3807, 13141, 13141, 13141, 13141, 13141, 13141, 13141, 13141, 13141, 13141, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 232, 232, 232, 232, 232, 232, 232, 232, 26184, 26184, 26184, 26184, 26184, 26184, 26184, 26184, 7699, 7699, 7699, 7699, 7699, 7699, 7699, 7699, 7699, 7699, 4308, 4308, 4308, 4308, 4308, 4308, 4308, 4308, 4308, 4308, 13141, 13141, 13141, 13141, 16456, 16456, 46, 46, 46, 46, 46, 46, 46, 46, 359, 359, 359, 359, 359, 359, 359, 359, 8761, 8761, 8761, 8761, 8761,  ...
# R is 2 Corrected R is 0 The index is 0
# R is 4 Corrected R is 1 The index is 1
# R is 1 Corrected R is 1 The index is 2
# R is 5 Corrected R is 3 The index is 3
# R is 2 Corrected R is 2 The index is 4
# R is 5 Corrected R is 5 The index is 5
# R is 1 Corrected R is 1 The index is 6
# R is 1 Corrected R is 1 The index is 7
# R is 2 Corrected R is 2 The index is 8
# R is 1 Corrected R is 1 The index is 9
# R is 2 Corrected R is 2 The index is 10
# R is 1 Corrected R is 1 The index is 11
# R is 1 Corrected R is 1 The index is 12
# R is 2 Corrected R is 2 The index is 13
# R is 4 Corrected R is 4 The index is 14
# R is 1 Corrected R is 1 The index is 15
# R is 2 Corrected R is 2 The index is 16
# R is 5 Corrected R is 5 The index is 17
# R is 5 Corrected R is 5 The index is 18
# R is 5 Corrected R is 5 The index is 19
# R is 1 Corrected R is 1 The index is 20
# R is 3 Corrected R is 3 The index is 21
# R is 3 Corrected R is 3 The index is 22
# R is 4 Corrected R is 4 The index is 23
# R is 4 Corrected R is 4 The index is 24
# R is 2 Corrected R is 2 The index is 25
# R is 1 Corrected R is 1 The index is 26
# R is 5 Corrected R is 5 The index is 27
# R is 3 Corrected R is 3 The index is 28
# R is 1 Corrected R is 1 The index is 29
# R is 3 Corrected R is 3 The index is 30
# R is 3 Corrected R is 3 The index is 31
# R is 2 Corrected R is 2 The index is 32
# R is 5 Corrected R is 5 The index is 33
# R is 5 Corrected R is 5 The index is 34
# R is 1 Corrected R is 1 The index is 35
# R is 1 Corrected R is 1 The index is 36
# R is 3 Corrected R is 3 The index is 37
# R is 5 Corrected R is 5 The index is 38
# R is 5 Corrected R is 5 The index is 39
# R is 3 Corrected R is 3 The index is 40
# R is 2 Corrected R is 2 The index is 41
# R is 1 Corrected R is 1 The index is 42
# R is 2 Corrected R is 2 The index is 43
# R is 4 Corrected R is 4 The index is 44
# R is 1 Corrected R is 1 The index is 45
# R is 3 Corrected R is 3 The index is 46
# R is 3 Corrected R is 3 The index is 47
# R is 5 Corrected R is 5 The index is 48
# R is 3 Corrected R is 3 The index is 49
# R is 5 Corrected R is 5 The index is 50
# R is 2 Corrected R is 2 The index is 51
# R is 2 Corrected R is 2 The index is 52
# R is 1 Corrected R is 1 The index is 53
# R is 2 Corrected R is 2 The index is 54
# R is 5 Corrected R is 5 The index is 55
# R is 3 Corrected R is 3 The index is 56
# R is 3 Corrected R is 3 The index is 57
# R is 5 Corrected R is 5 The index is 58
# R is 3 Corrected R is 3 The index is 59
# R is 1 Corrected R is 1 The index is 60
# R is 3 Corrected R is 3 The index is 61
# R is 1 Corrected R is 1 The index is 62
# R is 2 Corrected R is 2 The index is 63
# R is 3 Corrected R is 3 The index is 64
# R is 1 Corrected R is 1 The index is 65
# R is 5 Corrected R is 5 The index is 66
# R is 4 Corrected R is 4 The index is 67
# R is 4 Corrected R is 4 The index is 68
# R is 3 Corrected R is 3 The index is 69
# R is 5 Corrected R is 5 The index is 70
# R is 2 Corrected R is 2 The index is 71
# R is 4 Corrected R is 4 The index is 72
# R is 5 Corrected R is 5 The index is 73
# R is 2 Corrected R is 2 The index is 74
# R is 5 Corrected R is 5 The index is 75
# R is 3 Corrected R is 3 The index is 76
# R is 4 Corrected R is 4 The index is 77
# R is 4 Corrected R is 4 The index is 78
# R is 5 Corrected R is 5 The index is 79
# R is 4 Corrected R is 4 The index is 80
# R is 2 Corrected R is 2 The index is 81
# R is 4 Corrected R is 4 The index is 82
# R is 3 Corrected R is 3 The index is 83
# R is 2 Corrected R is 2 The index is 84
# R is 4 Corrected R is 4 The index is 85
# R is 2 Corrected R is 2 The index is 86
# R is 1 Corrected R is 1 The index is 87
# R is 3 Corrected R is 3 The index is 88
# R is 5 Corrected R is 5 The index is 89
# R is 1 Corrected R is 1 The index is 90
# R is 1 Corrected R is 1 The index is 91
# R is 2 Corrected R is 2 The index is 92
# R is 5 Corrected R is 5 The index is 93
# R is 2 Corrected R is 2 The index is 94
# R is 5 Corrected R is 5 The index is 95
# R is 2 Corrected R is 2 The index is 96
# R is 1 Corrected R is 1 The index is 97
# R is 2 Corrected R is 2 The index is 98
# R is 5 Corrected R is 5 The index is 99
# R is 1 Corrected R is 1 The index is 100
# R is 1 Corrected R is 1 The index is 101
# R is 4 Corrected R is 4 The index is 102
# R is 4 Corrected R is 4 The index is 103
# R is 1 Corrected R is 1 The index is 104
# R is 4 Corrected R is 4 The index is 105
# R is 5 Corrected R is 5 The index is 106
# R is 4 Corrected R is 4 The index is 107
# R is 4 Corrected R is 4 The index is 108
# R is 4 Corrected R is 4 The index is 109
# R is 4 Corrected R is 4 The index is 110
# R is 4 Corrected R is 4 The index is 111
# R is 2 Corrected R is 2 The index is 112
# R is 4 Corrected R is 4 The index is 113
# R is 5 Corrected R is 5 The index is 114
# R is 3 Corrected R is 3 The index is 115
# R is 4 Corrected R is 4 The index is 116
# R is 1 Corrected R is 1 The index is 117
# R is 2 Corrected R is 2 The index is 118
# R is 5 Corrected R is 5 The index is 119
# R is 5 Corrected R is 5 The index is 120
# R is 1 Corrected R is 1 The index is 121
# R is 5 Corrected R is 5 The index is 122
# R is 2 Corrected R is 2 The index is 123
# R is 2 Corrected R is 2 The index is 124
# R is 4 Corrected R is 4 The index is 125
# R is 2 Corrected R is 2 The index is 126
# R is 4 Corrected R is 4 The index is 127
# R is 2 Corrected R is 2 The index is 128
# R is 3 Corrected R is 3 The index is 129
# R is 2 Corrected R is 2 The index is 130
# R is 3 Corrected R is 3 The index is 131
# R is 5 Corrected R is 5 The index is 132
# R is 4 Corrected R is 4 The index is 133
# R is 4 Corrected R is 4 The index is 134
# R is 2 Corrected R is 2 The index is 135
# R is 1 Corrected R is 1 The index is 136
# R is 2 Corrected R is 2 The index is 137
# R is 4 Corrected R is 4 The index is 138
# R is 3 Corrected R is 3 The index is 139
# R is 3 Corrected R is 3 The index is 140
# R is 3 Corrected R is 3 The index is 141
# R is 3 Corrected R is 3 The index is 142
# R is 2 Corrected R is 2 The index is 143
# R is 1 Corrected R is 1 The index is 144
# R is 3 Corrected R is 3 The index is 145
# R is 4 Corrected R is 4 The index is 146
# R is 4 Corrected R is 4 The index is 147
# R is 5 Corrected R is 5 The index is 148
# R is 4 Corrected R is 4 The index is 149
# R is 3 Corrected R is 3 The index is 150
# R is 1 Corrected R is 1 The index is 151
# R is 2 Corrected R is 2 The index is 152
# R is 5 Corrected R is 5 The index is 153
# R is 3 Corrected R is 3 The index is 154
# R is 3 Corrected R is 3 The index is 155
# R is 3 Corrected R is 3 The index is 156
# R is 3 Corrected R is 3 The index is 157
# R is 1 Corrected R is 1 The index is 158
# R is 2 Corrected R is 2 The index is 159
# R is 5 Corrected R is 5 The index is 160
# R is 2 Corrected R is 2 The index is 161
# R is 3 Corrected R is 3 The index is 162
# R is 2 Corrected R is 2 The index is 163
# R is 3 Corrected R is 3 The index is 164
# R is 4 Corrected R is 4 The index is 165
# R is 1 Corrected R is 1 The index is 166
# R is 3 Corrected R is 3 The index is 167
# R is 4 Corrected R is 4 The index is 168
# R is 3 Corrected R is 3 The index is 169
# R is 5 Corrected R is 5 The index is 170
# R is 2 Corrected R is 2 The index is 171
# R is 5 Corrected R is 5 The index is 172
# R is 1 Corrected R is 1 The index is 173
# R is 2 Corrected R is 2 The index is 174
# R is 1 Corrected R is 1 The index is 175
# R is 5 Corrected R is 5 The index is 176
# R is 2 Corrected R is 2 The index is 177
# R is 4 Corrected R is 4 The index is 178
# R is 1 Corrected R is 1 The index is 179
# R is 1 Corrected R is 1 The index is 180
# R is 5 Corrected R is 5 The index is 181
# R is 4 Corrected R is 4 The index is 182
# R is 5 Corrected R is 5 The index is 183
# R is 1 Corrected R is 1 The index is 184
# R is 5 Corrected R is 5 The index is 185
# R is 2 Corrected R is 2 The index is 186
# R is 4 Corrected R is 4 The index is 187
# R is 3 Corrected R is 3 The index is 188
# R is 2 Corrected R is 2 The index is 189
# R is 1 Corrected R is 1 The index is 190
# R is 3 Corrected R is 3 The index is 191
# R is 5 Corrected R is 5 The index is 192
# R is 1 Corrected R is 1 The index is 193
# R is 2 Corrected R is 2 The index is 194
# R is 5 Corrected R is 5 The index is 195
# R is 3 Corrected R is 3 The index is 196
# R is 5 Corrected R is 5 The index is 197
# R is 2 Corrected R is 2 The index is 198
# R is 2 Corrected R is 2 The index is 199
# R is 1 Corrected R is 1 The index is 200
# R is 3 Corrected R is 3 The index is 201
# R is 4 Corrected R is 4 The index is 202
# R is 2 Corrected R is 2 The index is 203
# R is 5 Corrected R is 5 The index is 204
# R is 4 Corrected R is 4 The index is 205
# R is 4 Corrected R is 4 The index is 206
# R is 2 Corrected R is 2 The index is 207
# R is 2 Corrected R is 2 The index is 208
# R is 5 Corrected R is 5 The index is 209
# R is 3 Corrected R is 3 The index is 210
# R is 1 Corrected R is 1 The index is 211
# R is 4 Corrected R is 4 The index is 212
# R is 5 Corrected R is 5 The index is 213
# R is 2 Corrected R is 2 The index is 214
# R is 1 Corrected R is 1 The index is 215
# R is 1 Corrected R is 1 The index is 216
# R is 5 Corrected R is 5 The index is 217
# R is 5 Corrected R is 5 The index is 218
# R is 2 Corrected R is 2 The index is 219
# R is 4 Corrected R is 4 The index is 220
# R is 2 Corrected R is 2 The index is 221
# R is 2 Corrected R is 2 The index is 222
# R is 2 Corrected R is 2 The index is 223
# R is 4 Corrected R is 4 The index is 224
# R is 3 Corrected R is 3 The index is 225
# R is 5 Corrected R is 5 The index is 226
# R is 3 Corrected R is 3 The index is 227
# R is 1 Corrected R is 1 The index is 228
# R is 2 Corrected R is 2 The index is 229
# R is 1 Corrected R is 1 The index is 230
# R is 2 Corrected R is 2 The index is 231
# R is 5 Corrected R is 5 The index is 232
# R is 4 Corrected R is 4 The index is 233
# R is 1 Corrected R is 1 The index is 234
# R is 1 Corrected R is 1 The index is 235
# R is 1 Corrected R is 1 The index is 236
# R is 4 Corrected R is 4 The index is 237
# R is 1 Corrected R is 1 The index is 238
# R is 5 Corrected R is 5 The index is 239
# R is 3 Corrected R is 3 The index is 240
# R is 3 Corrected R is 3 The index is 241
# R is 1 Corrected R is 1 The index is 242
# R is 2 Corrected R is 2 The index is 243
# R is 3 Corrected R is 3 The index is 244
# R is 2 Corrected R is 2 The index is 245
# R is 2 Corrected R is 2 The index is 246
# R is 5 Corrected R is 5 The index is 247
# R is 2 Corrected R is 2 The index is 248
# R is 2 Corrected R is 2 The index is 249
# R is 2 Corrected R is 2 The index is 250
# R is 3 Corrected R is 3 The index is 251
# R is 1 Corrected R is 1 The index is 252
# R is 2 Corrected R is 2 The index is 253
# R is 4 Corrected R is 4 The index is 254
# R is 3 Corrected R is 3 The index is 255
# R is 5 Corrected R is 5 The index is 256
# R is 3 Corrected R is 3 The index is 257
# R is 5 Corrected R is 5 The index is 258
# R is 4 Corrected R is 4 The index is 259
# R is 1 Corrected R is 1 The index is 260
# R is 4 Corrected R is 4 The index is 261
# R is 2 Corrected R is 2 The index is 262
# R is 2 Corrected R is 2 The index is 263
# R is 5 Corrected R is 5 The index is 264
# R is 5 Corrected R is 5 The index is 265
# R is 1 Corrected R is 1 The index is 266
# R is 3 Corrected R is 3 The index is 267
# R is 5 Corrected R is 5 The index is 268
# R is 3 Corrected R is 3 The index is 269
# R is 3 Corrected R is 3 The index is 270
# R is 1 Corrected R is 1 The index is 271
# R is 2 Corrected R is 2 The index is 272
# R is 4 Corrected R is 4 The index is 273
# R is 4 Corrected R is 4 The index is 274
# R is 3 Corrected R is 3 The index is 275
# R is 4 Corrected R is 4 The index is 276
# R is 1 Corrected R is 1 The index is 277
# R is 2 Corrected R is 2 The index is 278
# R is 2 Corrected R is 2 The index is 279
# R is 5 Corrected R is 5 The index is 280
# R is 3 Corrected R is 3 The index is 281
# R is 4 Corrected R is 4 The index is 282
# R is 3 Corrected R is 3 The index is 283
# R is 1 Corrected R is 1 The index is 284
# R is 1 Corrected R is 1 The index is 285
# R is 5 Corrected R is 5 The index is 286
# R is 3 Corrected R is 3 The index is 287
# R is 1 Corrected R is 1 The index is 288
# R is 1 Corrected R is 1 The index is 289
# R is 5 Corrected R is 5 The index is 290
# R is 5 Corrected R is 5 The index is 291
# R is 3 Corrected R is 3 The index is 292
# R is 3 Corrected R is 3 The index is 293
# R is 4 Corrected R is 4 The index is 294
# R is 5 Corrected R is 5 The index is 295
# R is 1 Corrected R is 1 The index is 296
# R is 5 Corrected R is 5 The index is 297
# R is 3 Corrected R is 3 The index is 298
# R is 4 Corrected R is 4 The index is 299
# R is 4 Corrected R is 4 The index is 300
# R is 1 Corrected R is 1 The index is 301
# R is 4 Corrected R is 4 The index is 302
# R is 3 Corrected R is 3 The index is 303
# R is 1 Corrected R is 1 The index is 304
# R is 2 Corrected R is 2 The index is 305
# R is 5 Corrected R is 5 The index is 306
# R is 2 Corrected R is 2 The index is 307
# R is 3 Corrected R is 3 The index is 308
# R is 3 Corrected R is 3 The index is 309
# R is 2 Corrected R is 2 The index is 310
# R is 2 Corrected R is 2 The index is 311
# R is 1 Corrected R is 1 The index is 312
# R is 3 Corrected R is 3 The index is 313
# R is 1 Corrected R is 1 The index is 314
# R is 2 Corrected R is 2 The index is 315
# R is 5 Corrected R is 5 The index is 316
# R is 4 Corrected R is 4 The index is 317
# R is 1 Corrected R is 1 The index is 318
# R is 3 Corrected R is 3 The index is 319
# R is 2 Corrected R is 2 The index is 320
# R is 4 Corrected R is 4 The index is 321
# R is 3 Corrected R is 3 The index is 322
# R is 3 Corrected R is 3 The index is 323
# R is 1 Corrected R is 1 The index is 324
# R is 1 Corrected R is 1 The index is 325
# R is 2 Corrected R is 2 The index is 326
# R is 3 Corrected R is 3 The index is 327
# R is 5 Corrected R is 5 The index is 328
# R is 2 Corrected R is 2 The index is 329
# R is 1 Corrected R is 1 The index is 330
# R is 1 Corrected R is 1 The index is 331
# R is 2 Corrected R is 2 The index is 332
# R is 3 Corrected R is 3 The index is 333
# R is 1 Corrected R is 1 The index is 334
# R is 2 Corrected R is 2 The index is 335
# R is 2 Corrected R is 2 The index is 336
# R is 1 Corrected R is 1 The index is 337
# R is 3 Corrected R is 3 The index is 338
# R is 1 Corrected R is 1 The index is 339
# R is 5 Corrected R is 5 The index is 340
# R is 2 Corrected R is 2 The index is 341
# R is 2 Corrected R is 2 The index is 342
# R is 5 Corrected R is 5 The index is 343
# R is 4 Corrected R is 4 The index is 344
# R is 5 Corrected R is 5 The index is 345
# R is 5 Corrected R is 5 The index is 346
# R is 2 Corrected R is 2 The index is 347
# R is 5 Corrected R is 5 The index is 348
# R is 1 Corrected R is 1 The index is 349
# R is 2 Corrected R is 2 The index is 350
# R is 3 Corrected R is 3 The index is 351
# R is 1 Corrected R is 1 The index is 352
# R is 5 Corrected R is 5 The index is 353
# R is 2 Corrected R is 2 The index is 354
# R is 1 Corrected R is 1 The index is 355
# R is 5 Corrected R is 5 The index is 356
# R is 5 Corrected R is 5 The index is 357
# R is 2 Corrected R is 2 The index is 358
# R is 3 Corrected R is 3 The index is 359
# R is 3 Corrected R is 3 The index is 360
# R is 4 Corrected R is 4 The index is 361
# R is 4 Corrected R is 4 The index is 362
# R is 4 Corrected R is 4 The index is 363
# R is 5 Corrected R is 5 The index is 364
# R is 2 Corrected R is 2 The index is 365
# R is 3 Corrected R is 3 The index is 366
# R is 3 Corrected R is 3 The index is 367
# R is 1 Corrected R is 1 The index is 368
# R is 3 Corrected R is 3 The index is 369
# R is 1 Corrected R is 1 The index is 370
# R is 4 Corrected R is 4 The index is 371
# R is 4 Corrected R is 4 The index is 372
# R is 1 Corrected R is 1 The index is 373
# R is 1 Corrected R is 1 The index is 374
# R is 5 Corrected R is 5 The index is 375
# R is 3 Corrected R is 3 The index is 376
# R is 2 Corrected R is 2 The index is 377
# R is 2 Corrected R is 2 The index is 378
# R is 5 Corrected R is 5 The index is 379
# R is 4 Corrected R is 4 The index is 380
# R is 3 Corrected R is 3 The index is 381
# R is 2 Corrected R is 2 The index is 382
# R is 2 Corrected R is 2 The index is 383
# R is 1 Corrected R is 1 The index is 384
# R is 2 Corrected R is 2 The index is 385
# R is 3 Corrected R is 3 The index is 386
# R is 3 Corrected R is 3 The index is 387
# R is 1 Corrected R is 1 The index is 388
# R is 5 Corrected R is 5 The index is 389
# R is 3 Corrected R is 3 The index is 390
# R is 1 Corrected R is 1 The index is 391
# R is 3 Corrected R is 3 The index is 392
# R is 4 Corrected R is 4 The index is 393
# R is 1 Corrected R is 1 The index is 394
# R is 5 Corrected R is 5 The index is 395
# R is 3 Corrected R is 3 The index is 396
# R is 2 Corrected R is 2 The index is 397
# R is 4 Corrected R is 4 The index is 398
# R is 5 Corrected R is 5 The index is 399
# R is 5 Corrected R is 5 The index is 400
# R is 3 Corrected R is 3 The index is 401
# R is 1 Corrected R is 1 The index is 402
# R is 2 Corrected R is 2 The index is 403
# R is 4 Corrected R is 4 The index is 404
# R is 2 Corrected R is 2 The index is 405
# R is 5 Corrected R is 5 The index is 406
# R is 5 Corrected R is 5 The index is 407
# R is 3 Corrected R is 3 The index is 408
# R is 4 Corrected R is 4 The index is 409
# R is 3 Corrected R is 3 The index is 410
# R is 2 Corrected R is 2 The index is 411
# R is 2 Corrected R is 2 The index is 412
# R is 4 Corrected R is 4 The index is 413
# R is 1 Corrected R is 1 The index is 414
# R is 4 Corrected R is 4 The index is 415
# R is 3 Corrected R is 3 The index is 416
# R is 2 Corrected R is 2 The index is 417
# R is 3 Corrected R is 3 The index is 418
# R is 4 Corrected R is 4 The index is 419
# R is 2 Corrected R is 2 The index is 420
# R is 2 Corrected R is 2 The index is 421
# R is 2 Corrected R is 2 The index is 422
# R is 4 Corrected R is 4 The index is 423
# R is 3 Corrected R is 3 The index is 424
# R is 5 Corrected R is 5 The index is 425
# R is 1 Corrected R is 1 The index is 426
# R is 4 Corrected R is 4 The index is 427
# R is 1 Corrected R is 1 The index is 428
# R is 2 Corrected R is 2 The index is 429
# R is 1 Corrected R is 1 The index is 430
# R is 4 Corrected R is 4 The index is 431
# R is 1 Corrected R is 1 The index is 432
# R is 3 Corrected R is 3 The index is 433
# R is 5 Corrected R is 5 The index is 434
# R is 3 Corrected R is 3 The index is 435
# R is 2 Corrected R is 2 The index is 436
# R is 4 Corrected R is 4 The index is 437
# R is 3 Corrected R is 3 The index is 438
# R is 4 Corrected R is 4 The index is 439
# R is 2 Corrected R is 2 The index is 440
# R is 4 Corrected R is 4 The index is 441
# R is 3 Corrected R is 3 The index is 442
# R is 4 Corrected R is 4 The index is 443
# R is 2 Corrected R is 2 The index is 444
# R is 1 Corrected R is 1 The index is 445
# R is 4 Corrected R is 4 The index is 446
# R is 2 Corrected R is 2 The index is 447
# R is 5 Corrected R is 5 The index is 448
# R is 3 Corrected R is 3 The index is 449
# R is 2 Corrected R is 2 The index is 450
# R is 1 Corrected R is 1 The index is 451
# R is 5 Corrected R is 5 The index is 452
# R is 3 Corrected R is 3 The index is 453
# R is 1 Corrected R is 1 The index is 454
# R is 3 Corrected R is 3 The index is 455
# R is 5 Corrected R is 5 The index is 456
# R is 1 Corrected R is 1 The index is 457
# R is 1 Corrected R is 1 The index is 458
# R is 3 Corrected R is 3 The index is 459
# R is 5 Corrected R is 5 The index is 460
# R is 2 Corrected R is 2 The index is 461
# R is 2 Corrected R is 2 The index is 462
# R is 1 Corrected R is 1 The index is 463
# R is 1 Corrected R is 1 The index is 464
# R is 3 Corrected R is 3 The index is 465
# R is 3 Corrected R is 3 The index is 466
# R is 1 Corrected R is 1 The index is 467
# R is 2 Corrected R is 2 The index is 468
# R is 5 Corrected R is 5 The index is 469
# R is 2 Corrected R is 2 The index is 470
# R is 3 Corrected R is 3 The index is 471
# R is 3 Corrected R is 3 The index is 472
# R is 5 Corrected R is 5 The index is 473
# R is 3 Corrected R is 3 The index is 474
# R is 4 Corrected R is 4 The index is 475
# R is 4 Corrected R is 4 The index is 476
# R is 5 Corrected R is 5 The index is 477
# R is 3 Corrected R is 3 The index is 478
# R is 5 Corrected R is 5 The index is 479
# R is 2 Corrected R is 2 The index is 480
# R is 3 Corrected R is 3 The index is 481
# R is 1 Corrected R is 1 The index is 482
# R is 2 Corrected R is 2 The index is 483
# R is 5 Corrected R is 5 The index is 484
# R is 3 Corrected R is 3 The index is 485
# R is 5 Corrected R is 5 The index is 486
# R is 1 Corrected R is 1 The index is 487
# R is 3 Corrected R is 3 The index is 488
# R is 2 Corrected R is 2 The index is 489
# R is 4 Corrected R is 4 The index is 490
# R is 5 Corrected R is 5 The index is 491
# R is 5 Corrected R is 5 The index is 492
# R is 1 Corrected R is 1 The index is 493
# R is 3 Corrected R is 3 The index is 494
# R is 5 Corrected R is 5 The index is 495
# R is 4 Corrected R is 4 The index is 496
# R is 1 Corrected R is 1 The index is 497
# R is 3 Corrected R is 3 The index is 498
# R is 5 Corrected R is 5 The index is 499
# R is 5 Corrected R is 5 The index is 500
# R is 3 Corrected R is 3 The index is 501
# R is 2 Corrected R is 2 The index is 502
# R is 1 Corrected R is 1 The index is 503
# R is 2 Corrected R is 2 The index is 504
# R is 3 Corrected R is 3 The index is 505
# R is 2 Corrected R is 2 The index is 506
# R is 2 Corrected R is 2 The index is 507
# R is 1 Corrected R is 1 The index is 508
# R is 3 Corrected R is 3 The index is 509
# R is 2 Corrected R is 2 The index is 510
# R is 4 Corrected R is 4 The index is 511
# ...
# R is 2 Corrected R is 2 The index is 231
# R is 2 Corrected R is 2 The index is 232
# R is 1 Corrected R is 1 The index is 233
# R is 3 Corrected R is 3 The index is 234
# R is 2 Corrected R is 2 The index is 235
# R is 2 Corrected R is 2 The index is 236
# R is 5 Corrected R is 5 The index is 237
# R is 2 Corrected R is 2 The index is 238
# R is 4 Corrected R is 4 The index is 239
# R is 5 Corrected R is 5 The index is 240
# R is 3 Corrected R is 3 The index is 241
# R is 3 Corrected R is 3 The index is 242
# R is 5 Corrected R is 5 The index is 243
# R is 1 Corrected R is 1 The index is 244
# R is 4 Corrected R is 4 The index is 245
# R is 3 Corrected R is 3 The index is 246
# R is 3 Corrected R is 3 The index is 247
# R is 3 Corrected R is 3 The index is 248
# R is 1 Corrected R is 1 The index is 249
# R is 5 Corrected R is 5 The index is 250
# R is 4 Corrected R is 4 The index is 251
# R is 5 Corrected R is 5 The index is 252
# R is 4 Corrected R is 4 The index is 253
# R is 5 Corrected R is 5 The index is 254
# R is 2 Corrected R is 2 The index is 255
# R is 1 Corrected R is 1 The index is 256
# R is 2 Corrected R is 2 The index is 257
# R is 4 Corrected R is 4 The index is 258
# R is 4 Corrected R is 4 The index is 259
# R is 4 Corrected R is 4 The index is 260
# R is 3 Corrected R is 3 The index is 261
# R is 5 Corrected R is 5 The index is 262
# R is 4 Corrected R is 4 The index is 263
# R is 1 Corrected R is 1 The index is 264
# R is 1 Corrected R is 1 The index is 265
# R is 3 Corrected R is 3 The index is 266
# R is 3 Corrected R is 3 The index is 267
# R is 4 Corrected R is 4 The index is 268
# R is 2 Corrected R is 2 The index is 269
# R is 4 Corrected R is 4 The index is 270
# R is 1 Corrected R is 1 The index is 271
# R is 5 Corrected R is 5 The index is 272
# R is 1 Corrected R is 1 The index is 273
# R is 1 Corrected R is 1 The index is 274
# R is 4 Corrected R is 4 The index is 275
# R is 4 Corrected R is 4 The index is 276
# R is 4 Corrected R is 4 The index is 277
# R is 5 Corrected R is 5 The index is 278
# R is 5 Corrected R is 5 The index is 279
# R is 4 Corrected R is 4 The index is 280
# R is 1 Corrected R is 1 The index is 281
# R is 4 Corrected R is 4 The index is 282
# R is 4 Corrected R is 4 The index is 283
# R is 5 Corrected R is 5 The index is 284
# R is 5 Corrected R is 5 The index is 285
# R is 5 Corrected R is 5 The index is 286
# R is 2 Corrected R is 2 The index is 287
# R is 5 Corrected R is 5 The index is 288
# R is 1 Corrected R is 1 The index is 289
# R is 3 Corrected R is 3 The index is 290
# R is 2 Corrected R is 2 The index is 291
# R is 4 Corrected R is 4 The index is 292
# R is 3 Corrected R is 3 The index is 293
# R is 4 Corrected R is 4 The index is 294
# R is 3 Corrected R is 3 The index is 295
# R is 1 Corrected R is 1 The index is 296
# R is 2 Corrected R is 2 The index is 297
# R is 2 Corrected R is 2 The index is 298
# R is 2 Corrected R is 2 The index is 299
# R is 4 Corrected R is 4 The index is 300
# R is 3 Corrected R is 3 The index is 301
# R is 2 Corrected R is 2 The index is 302
# R is 1 Corrected R is 1 The index is 303
# R is 1 Corrected R is 1 The index is 304
# R is 2 Corrected R is 2 The index is 305
# R is 3 Corrected R is 3 The index is 306
# R is 4 Corrected R is 4 The index is 307
# R is 3 Corrected R is 3 The index is 308
# R is 2 Corrected R is 2 The index is 309
# R is 1 Corrected R is 1 The index is 310
# R is 5 Corrected R is 5 The index is 311
# R is 3 Corrected R is 3 The index is 312
# R is 4 Corrected R is 4 The index is 313
# R is 3 Corrected R is 3 The index is 314
# R is 5 Corrected R is 5 The index is 315
# R is 5 Corrected R is 5 The index is 316
# R is 3 Corrected R is 3 The index is 317
# R is 1 Corrected R is 1 The index is 318
# R is 1 Corrected R is 1 The index is 319
# R is 4 Corrected R is 4 The index is 320
# R is 5 Corrected R is 5 The index is 321
# R is 4 Corrected R is 4 The index is 322
# R is 1 Corrected R is 1 The index is 323
# R is 1 Corrected R is 1 The index is 324
# R is 3 Corrected R is 3 The index is 325
# R is 4 Corrected R is 4 The index is 326
# R is 2 Corrected R is 2 The index is 327
# R is 1 Corrected R is 1 The index is 328
# R is 2 Corrected R is 2 The index is 329
# R is 2 Corrected R is 2 The index is 330
# R is 2 Corrected R is 2 The index is 331
# R is 3 Corrected R is 3 The index is 332
# R is 4 Corrected R is 4 The index is 333
# R is 2 Corrected R is 2 The index is 334
# R is 1 Corrected R is 1 The index is 335
# R is 5 Corrected R is 5 The index is 336
# R is 3 Corrected R is 3 The index is 337
# R is 4 Corrected R is 4 The index is 338
# R is 5 Corrected R is 5 The index is 339
# R is 4 Corrected R is 4 The index is 340
# R is 2 Corrected R is 2 The index is 341
# R is 5 Corrected R is 5 The index is 342
# R is 3 Corrected R is 3 The index is 343
# R is 1 Corrected R is 1 The index is 344
# R is 4 Corrected R is 4 The index is 345
# R is 3 Corrected R is 3 The index is 346
# R is 3 Corrected R is 3 The index is 347
# R is 2 Corrected R is 2 The index is 348
# R is 1 Corrected R is 1 The index is 349
# R is 5 Corrected R is 5 The index is 350
# R is 2 Corrected R is 2 The index is 351
# R is 2 Corrected R is 2 The index is 352
# R is 3 Corrected R is 3 The index is 353
# R is 2 Corrected R is 2 The index is 354
# R is 3 Corrected R is 3 The index is 355
# R is 3 Corrected R is 3 The index is 356
# R is 2 Corrected R is 2 The index is 357
# R is 2 Corrected R is 2 The index is 358
# R is 5 Corrected R is 5 The index is 359
# R is 5 Corrected R is 5 The index is 360
# R is 5 Corrected R is 5 The index is 361
# R is 4 Corrected R is 4 The index is 362
# R is 5 Corrected R is 5 The index is 363
# R is 4 Corrected R is 4 The index is 364
# R is 3 Corrected R is 3 The index is 365
# R is 4 Corrected R is 4 The index is 366
# R is 4 Corrected R is 4 The index is 367
# R is 3 Corrected R is 3 The index is 368
# R is 2 Corrected R is 2 The index is 369
# R is 1 Corrected R is 1 The index is 370
# R is 4 Corrected R is 4 The index is 371
# R is 1 Corrected R is 1 The index is 372
# R is 5 Corrected R is 5 The index is 373
# R is 4 Corrected R is 4 The index is 374
# R is 4 Corrected R is 4 The index is 375
# R is 5 Corrected R is 5 The index is 376
# R is 2 Corrected R is 2 The index is 377
# R is 4 Corrected R is 4 The index is 378
# R is 4 Corrected R is 4 The index is 379
# R is 5 Corrected R is 5 The index is 380
# R is 5 Corrected R is 5 The index is 381
# R is 5 Corrected R is 5 The index is 382
# R is 5 Corrected R is 5 The index is 383
# R is 4 Corrected R is 4 The index is 384
# R is 4 Corrected R is 4 The index is 385
# R is 1 Corrected R is 1 The index is 386
# R is 5 Corrected R is 5 The index is 387
# R is 4 Corrected R is 4 The index is 388
# R is 3 Corrected R is 3 The index is 389
# R is 2 Corrected R is 2 The index is 390
# R is 1 Corrected R is 1 The index is 391
# R is 1 Corrected R is 1 The index is 392
# R is 4 Corrected R is 4 The index is 393
# R is 2 Corrected R is 2 The index is 394
# R is 4 Corrected R is 4 The index is 395
# R is 5 Corrected R is 5 The index is 396
# R is 5 Corrected R is 5 The index is 397
# R is 1 Corrected R is 1 The index is 398
# R is 2 Corrected R is 2 The index is 399
# R is 2 Corrected R is 2 The index is 400
# R is 4 Corrected R is 4 The index is 401
# R is 3 Corrected R is 3 The index is 402
# R is 5 Corrected R is 5 The index is 403
# R is 2 Corrected R is 2 The index is 404
# R is 4 Corrected R is 4 The index is 405
# R is 5 Corrected R is 5 The index is 406
# R is 4 Corrected R is 4 The index is 407
# R is 2 Corrected R is 2 The index is 408
# R is 3 Corrected R is 3 The index is 409
# R is 5 Corrected R is 5 The index is 410
# R is 4 Corrected R is 4 The index is 411
# R is 4 Corrected R is 4 The index is 412
# R is 3 Corrected R is 3 The index is 413
# R is 3 Corrected R is 3 The index is 414
# R is 3 Corrected R is 3 The index is 415
# R is 2 Corrected R is 2 The index is 416
# R is 4 Corrected R is 4 The index is 417
# R is 2 Corrected R is 2 The index is 418
# R is 3 Corrected R is 3 The index is 419
# R is 2 Corrected R is 2 The index is 420
# R is 4 Corrected R is 4 The index is 421
# R is 5 Corrected R is 5 The index is 422
# R is 5 Corrected R is 5 The index is 423
# R is 2 Corrected R is 2 The index is 424
# R is 1 Corrected R is 1 The index is 425
# R is 1 Corrected R is 1 The index is 426
# R is 4 Corrected R is 4 The index is 427
# R is 1 Corrected R is 1 The index is 428
# R is 3 Corrected R is 3 The index is 429
# R is 5 Corrected R is 5 The index is 430
# R is 4 Corrected R is 4 The index is 431
# R is 5 Corrected R is 5 The index is 432
# R is 4 Corrected R is 4 The index is 433
# R is 4 Corrected R is 4 The index is 434
# R is 4 Corrected R is 4 The index is 435
# R is 1 Corrected R is 1 The index is 436
# R is 5 Corrected R is 5 The index is 437
# R is 1 Corrected R is 1 The index is 438
# R is 4 Corrected R is 4 The index is 439
# R is 1 Corrected R is 1 The index is 440
# R is 1 Corrected R is 1 The index is 441
# R is 1 Corrected R is 1 The index is 442
# R is 1 Corrected R is 1 The index is 443
# R is 3 Corrected R is 3 The index is 444
# R is 2 Corrected R is 2 The index is 445
# R is 3 Corrected R is 3 The index is 446
# R is 4 Corrected R is 4 The index is 447
# R is 5 Corrected R is 5 The index is 448
# R is 3 Corrected R is 3 The index is 449
# R is 4 Corrected R is 4 The index is 450
# R is 5 Corrected R is 5 The index is 451
# R is 4 Corrected R is 4 The index is 452
# R is 2 Corrected R is 2 The index is 453
# R is 5 Corrected R is 5 The index is 454
# R is 3 Corrected R is 3 The index is 455
# R is 1 Corrected R is 1 The index is 456
# R is 1 Corrected R is 1 The index is 457
# R is 4 Corrected R is 4 The index is 458
# R is 1 Corrected R is 1 The index is 459
# R is 4 Corrected R is 4 The index is 460
# R is 2 Corrected R is 2 The index is 461
# R is 5 Corrected R is 5 The index is 462
# R is 4 Corrected R is 4 The index is 463
# R is 4 Corrected R is 4 The index is 464
# R is 5 Corrected R is 5 The index is 465
# R is 3 Corrected R is 3 The index is 466
# R is 1 Corrected R is 1 The index is 467
# R is 5 Corrected R is 5 The index is 468
# R is 4 Corrected R is 4 The index is 469
# R is 3 Corrected R is 3 The index is 470
# R is 3 Corrected R is 3 The index is 471
# R is 1 Corrected R is 1 The index is 472
# R is 4 Corrected R is 4 The index is 473
# R is 2 Corrected R is 2 The index is 474
# R is 1 Corrected R is 1 The index is 475
# R is 4 Corrected R is 4 The index is 476
# R is 4 Corrected R is 4 The index is 477
# R is 2 Corrected R is 2 The index is 478
# R is 3 Corrected R is 3 The index is 479
# R is 1 Corrected R is 1 The index is 480
# R is 3 Corrected R is 3 The index is 481
# R is 2 Corrected R is 2 The index is 482
# R is 5 Corrected R is 5 The index is 483
# R is 4 Corrected R is 4 The index is 484
# R is 2 Corrected R is 2 The index is 485
# R is 4 Corrected R is 4 The index is 486
# R is 4 Corrected R is 4 The index is 487
# R is 5 Corrected R is 5 The index is 488
# R is 1 Corrected R is 1 The index is 489
# R is 3 Corrected R is 3 The index is 490
# R is 1 Corrected R is 1 The index is 491
# R is 4 Corrected R is 4 The index is 492
# R is 3 Corrected R is 3 The index is 493
# R is 1 Corrected R is 1 The index is 494
# R is 4 Corrected R is 4 The index is 495
# R is 4 Corrected R is 4 The index is 496
# R is 1 Corrected R is 1 The index is 497
# R is 4 Corrected R is 4 The index is 498
# R is 3 Corrected R is 3 The index is 499
# R is 4 Corrected R is 4 The index is 500
# R is 5 Corrected R is 5 The index is 501
# R is 5 Corrected R is 5 The index is 502
# R is 2 Corrected R is 2 The index is 503
# R is 5 Corrected R is 5 The index is 504
# R is 5 Corrected R is 5 The index is 505
# R is 2 Corrected R is 2 The index is 506
# R is 1 Corrected R is 1 The index is 507
# R is 1 Corrected R is 1 The index is 508
# R is 1 Corrected R is 1 The index is 509
# R is 4 Corrected R is 4 The index is 510
# R is 2 Corrected R is 2 The index is 511
# [11588, 11588, 11588, 11588, 11588, 244, 244, 244, 1019, 1019, 1019, 1019, 1019, 1019, 1019, 2, 2, 7121, 7121, 7121, 7121, 7121, 7121, 4338, 4338, 885, 885, 885, 885, 885, 885, 885, 885, 12655, 12655, 12655, 12655, 6756, 6756, 53753, 53753, 53753, 53753, 53753, 53753, 53753, 53753, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 2865, 1573, 1573, 4767, 4767, 4767, 4767, 4767, 4767, 4767, 4767, 4767, 4767, 1573, 1573, 1573, 1573, 1573, 1573, 290, 290, 290, 290, 290, 290, 2482, 2482, 2482, 2482, 2482, 2482, 2482, 2482, 2482, 2482, 10212, 10212, 10212, 10212, 10212, 10212, 15210, 15210, 15210, 15210, 4705, 4705, 4705, 4705, 4705, 4705, 4705, 4705, 4705, 4705, 1573, 1573, 1573, 1573, 12559, 12559, 12559, 12559, 12559, 12559, 12559, 12559, 16646, 16646, 16646, 16646, 16646, 16646, 2915, 2915, 2915, 2915, 2915, 2915, 2915, 2915, 2915, 2915, 3990, 3990, 3990, 3990, 3990, 3990, 3990, 3990, 3990, 3990, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 3742, 3742, 3742, 3742, 3742, 3742, 3742, 3742, 3742, 3742, 4, 4, 4, 4, 4, 4, 3353, 3353, 3353, 3353, 3353, 3353, 6244, 6244, 6244, 6244, 6244, 6244, 6244, 6244, 6244, 6244, 2349, 2349, 2349, 2349, 2349, 2349, 2349, 2349, 2349, 2349, 3496, 3496, 3496, 3496, 3496, 3496, 3496, 3496, 3496, 3496, 6979, 6979, 6979, 6979, 6979, 6979, 6979, 6979, 7352, 7352, 7352, 7352, 7961, 7961, 7961, 7961, 7961, 7961, 7961, 7961, 57, 57, 57, 57, 57, 57, 6439, 6439, 6439, 6439, 7518, 7518, 4446, 4446, 12854, 12854, 12854, 12854, 12854, 12854, 12854, 12854, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 595, 595, 9, 9, 9, 9, 9, 9, 2759, 2759, 2759, 2759, 2759, 2759, 2759, 2759, 2759, 2759, 4523, 4523, 4523, 4523, 4523, 4523, 4523, 4523, 6, 6, 6, 6, 766, 766, 766, 766, 766, 766, 766, 766, 2728, 2728, 2728, 2728, 2728, 2728, 2728, 2728, 26, 26, 26, 26, 26, 26, 26, 26, 4523, 4523, 4523, 4523, 1847, 1847, 1847, 1847, 81, 81, 81, 81, 81, 81, 2183, 2183, 2183, 2183, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 7894, 7894, 7894, 7894, 7894, 7894, 2, 2, 2, 2, 2, 2, 2482, 2482, 2482, 2482, 2482, 2482, 18986, 18986, 18986, 18986, 18986, 18986, 18986, 18986, 18986, 18986, 2759, 2759, 2759, 2759, 7894, 7894, 7894, 7894, 7894, 7894, 7894, 7894, 7894, 7894, 290, 290, 10212, 10212, 10212, 10212, 927, 927, 927, 927, 927, 927, 927, 927, 10212, 10212, 10212, 10212, 10212, 10212, 10212, 10212, 4865, 4865, 32832, 32832, 32832, 32832, 32832, 32832, 32832, 32832, 2183, 2183, 2183, 2183, 2183, 2183, 2183, 2183, 8892, 8892, 8892, 8892, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 1573, 21159, 21159, 21159, 21159, 21159, 21159, 13371, 13371, 13371, 13371, 13371, 13371, 12750, 12750, 12750, 12750, 12750, 12750, 12750, 12750, 12750, 12750, 36104, 36104, 36104, 36104, 36104, 36104, 1970, 1970, 1970, 1970, 3421, 3421, 3421, 3421, 3421, 3421, 3421, 3421, 3421, 3421, 4817, 4817, 4, 4, 4, 4, 12959, 12959, 12959, 12959, 12959, 12959, 12959, 12959, 12959, 12959, 1906, 1906, 1906, 1906, 1906, 1906, 12302, 12302, 12302, 12302, 12302, 12302, 13371, 13371, 13371, 13371, 13371, 13371, 13371, 13371, 13371, 13371, 12750, 12750, 12750, 12750, 13371, 13371, 13371, 13371, 13371, 13371, 13371, 13371, 12750, 12750, 12750, 12750, 12750, 12750, 12750, 12750, 8408, 8408, 8408, 8408, 8408, 8408, 8408, 8408, 4030, 4030, 1351, 1351, 1351, 1351, 1351, 1351, 1351, 1351, 22524, 22524, 22524, 22524, 22524, 22524, 22524, 22524, 1255, 1255, 1255, 1255, 1255, 1255, 1255, 1255, 1255, 1255, 2857, 2857, 2857, 2857, 83, 83, 83, 83, 59, 59, 59, 59, 59, 59, 59, 59, 27970, 27970, 27970, 27970, 27970, 27970, 27970, 27970, 2087, 2087, 2087, 2087, 6304, 6304, 6304, 6304, 6304, 6304, 6304, 6304, 6304, 6304, 3348, 3348, 515, 515, 8892, 8892, 8892, 8892, 2811, 2811, 2811, 2811, 2811, 2811, 2811, 2811, 2811, 2811, 13159, 13159, 13159, 13159, 4202, 4202, 4202, 4202, 4202, 4202, 58144, 58144, 58144, 58144, 58144, 58144, 58144, 58144, 58144, 58144, 9939, 9939, 4406, 4406, 4406, 4406, 4406, 4406, 4406, 4406, 2759, 2759, 2759, 2759, 2759, 2759, 2759, 2759, 1573, 1573, 1573, 157 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-25141cf86b80> in <module>()
#      20         steps += 1
#      21         inputs, targets = torch.LongTensor(inputs), torch.LongTensor(targets)
# ---> 22         inputs, targets = inputs.to(device), targets.to(device)
#      23
#      24         log_ps = model(inputs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
# getting embeddings from the embedding layer of our model, by name
embeddings = model.embed.weight.to('cpu').data.numpy()

# %%
viz_words = 600
tsne = TSNE()
embed_tsne = tsne.fit_transform(embeddings[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
